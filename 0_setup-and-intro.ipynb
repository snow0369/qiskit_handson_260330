# %% [markdown]
# ## Installation

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: qiskit~=2.3.0 in .\.venv\Lib\site-packages (from -r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: matplotlib~=3.10.8 in .\.venv\Lib\site-packages (from -r requirements.txt (line 2)) (3.10.8)
# Requirement already satisfied: jupyter~=1.1.1 in .\.venv\Lib\site-packages (from -r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: qiskit-ibm-runtime~=0.45.1 in .\.venv\Lib\site-packages (from -r requirements.txt (line 5)) (0.45.1)
# Requirement already satisfied: python-dotenv in .\.venv\Lib\site-packages (from -r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: pydot in .\.venv\Lib\site-packages (from -r requirements.txt (line 7)) (4.0.1)
# Requirement already satisfied: rustworkx>=0.15.0 in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: scipy>=1.5 in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: dill>=0.3 in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (5.7.0)
# Requirement already satisfied: typing-extensions in .\.venv\Lib\site-packages (from qiskit~=2.3.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pillow>=8 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib~=3.10.8->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: notebook in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (7.5.5)
# Requirement already satisfied: jupyter-console in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (6.6.3)
# Requirement already satisfied: nbconvert in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (7.17.0)
# Requirement already satisfied: ipykernel in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (7.2.0)
# Requirement already satisfied: ipywidgets in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: jupyterlab in .\.venv\Lib\site-packages (from jupyter~=1.1.1->-r requirements.txt (line 4)) (4.5.6)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in .\.venv\Lib\site-packages (from qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: requests-ntlm>=1.1.0 in .\.venv\Lib\site-packages (from qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in .\.venv\Lib\site-packages (from qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in .\.venv\Lib\site-packages (from qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (0.74.0)
# Requirement already satisfied: pydantic>=2.5.0 in .\.venv\Lib\site-packages (from qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: pylatexenc>=1.4 in .\.venv\Lib\site-packages (from qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in .\.venv\Lib\site-packages (from qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in .\.venv\Lib\site-packages (from qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in .\.venv\Lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in .\.venv\Lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.10.8->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\Lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2026.2.25)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\Lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: cryptography>=1.3 in .\.venv\Lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (46.0.5)
# Requirement already satisfied: pyspnego>=0.4.0 in .\.venv\Lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in .\.venv\Lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime~=0.45.1->-r requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: pandas>=1.2 in .\.venv\Lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.venv\Lib\site-packages (from sympy>=1.3->qiskit[visualization]~=2.3.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (9.11.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in .\.venv\Lib\site-packages (from ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: wcwidth in .\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.9.4)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: pure-eval in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\.venv\Lib\site-packages (from ipywidgets->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\.venv\Lib\site-packages (from ipywidgets->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (82.0.1)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in .\.venv\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: fqdn in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: uri-template in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in .\.venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (6.3.0)
# Requirement already satisfied: defusedxml in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in .\.venv\Lib\site-packages (from nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: webencodings in .\.venv\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in .\.venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in .\.venv\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in .\.venv\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\Lib\site-packages (from beautifulsoup4->nbconvert->jupyter~=1.1.1->-r requirements.txt (line 4)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in .\.venv\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter~=1.1.1->-r requirements.txt (line 4)) (1.4.0)

# %% [markdown]
# -------------
#
# ## Save IBM Account
# ![IQP_login.png](images/IQP_login.png)
# 1. Login [IBM Quantum Platform](https://quantum.cloud.ibm.com/).
# 2. Create and copy API Key.
# 3. Generate an `.env` file and write a line as follows:
# ```
# API_TOKEN=your_token
# ```

# %%
import os
from dotenv import load_dotenv
from qiskit_ibm_runtime import QiskitRuntimeService

load_dotenv()

api_token = os.getenv("API_TOKEN")
if not api_token:
    raise RuntimeError("API_TOKEN is not set")

QiskitRuntimeService.save_account(
    token=api_token,
    overwrite=True
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# -------------
#
# ## Useful Resources
#
# - Qiskit and IBM Quantum Documentations [https://quantum.cloud.ibm.com/docs/en/guides](https://quantum.cloud.ibm.com/docs/en/guides)
#
# ### Release
# - Qiskit 2.0 Release News [https://www.ibm.com/quantum/blog/qiskit-2-0-release-summary](https://www.ibm.com/quantum/blog/qiskit-2-0-release-summary)
# - Qiskit 2.1 Release News [https://www.ibm.com/quantum/blog/qiskit-2-1-release-summary](https://www.ibm.com/quantum/blog/qiskit-2-1-release-summary)
# - Qiskit 2.2 Release News [https://www.ibm.com/quantum/blog/qiskit-2-2-release-summary](https://www.ibm.com/quantum/blog/qiskit-2-1-release-summary)
# - Qiskit 2.3 Release News [https://www.ibm.com/quantum/blog/qiskit-2-3-release-summary](https://www.ibm.com/quantum/blog/qiskit-2-1-release-summary)
# - Full Release Notes [https://quantum.cloud.ibm.com/docs/en/api/qiskit/release-notes](https://quantum.cloud.ibm.com/docs/en/api/qiskit/release-notes)
# - 1.x -> 2.x Migration Guide [https://quantum.cloud.ibm.com/docs/en/guides/qiskit-2.0](https://quantum.cloud.ibm.com/docs/en/guides/qiskit-2.0)
#
# ### Qiskit Ecosystem
# -
#
# ### Learning
# - Qiskit Tutorials [https://quantum.cloud.ibm.com/docs/en/tutorials](https://quantum.cloud.ibm.com/docs/en/tutorials)
